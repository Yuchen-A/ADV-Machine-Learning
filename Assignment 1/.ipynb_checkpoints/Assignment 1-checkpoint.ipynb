# %% [markdown]
# # 1. Import datasets

# %%
import pandas as pd
X_train = pd.read_csv('world_happiness_competition_data/X_train.csv')
X_test = pd.read_csv('world_happiness_competition_data/X_test.csv')## Load test features to predict on
y_train = pd.read_csv('world_happiness_competition_data/y_train.csv')## Load y train (true labels)
y_test = pd.read_csv('world_happiness_competition_data/y_test.csv')## Load y test (true labels)
y_train_labels = y_train.idxmax(axis=1) ## Examine what this does and write in next cell
y_test_labels = y_test.idxmax(axis=1)## Complete in a similar manner as above

X_train.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0            Latvia           1.187           1.465                    0.812
# 1           Burundi           0.046           0.447                    0.380
# 2           Belarus           1.067           1.465                    0.789
# 3           Liberia           0.073           0.922                    0.443
# 4           Ecuador           0.912           1.312                    0.868
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         0.264       0.075                      0.064
# 1                         0.220       0.176                      0.180
# 2                         0.235       0.094                      0.142
# 3                         0.370       0.233                      0.033
# 4                         0.498       0.126                      0.087
#
#       name    region                       sub-region  Terrorist_attacks
# 0   Latvia    Europe                  Northern Europe         125.611111
# 1  Burundi    Africa               Sub-Saharan Africa         155.000000
# 2  Belarus    Europe                   Eastern Europe           4.000000
# 3  Liberia    Africa               Sub-Saharan Africa        1419.095238
# 4  Ecuador  Americas  Latin America and the Caribbean           5.000000

# %%
countrydata=pd.read_csv("newcountryvars.csv")

countrydata.head()
# Out:
#   country_name  population  population_below_poverty_line       hdi  \
# 0        India  1339180127                           21.9  0.623559
# 1      Nigeria   190886311                           70.0  0.527105
# 2       Mexico   129163276                           46.2  0.761683
# 3     Pakistan   197015955                           29.5  0.550354
# 4   Bangladesh   164669751                           31.5  0.578824
#
#    life_expectancy  expected_years_of_schooling  mean_years_of_schooling  \
# 0           68.322                    11.696590                 6.298834
# 1           53.057                     9.970482                 6.000000
# 2           76.972                    13.299090                 8.554985
# 3           66.365                     8.106910                 5.089460
# 4           71.985                    10.178706                 5.241577
#
#             gni
# 0   5663.474799
# 1   5442.901264
# 2  16383.106680
# 3   5031.173074
# 4   3341.490722

# %%
X_train = pd.merge(X_train, countrydata, left_on='Country or region', right_on='country_name', how='left')## Complete code
X_test = pd.merge(X_test, countrydata, left_on='Country or region', right_on='country_name', how='left')## Complete code

# %%
X_train.head(1)
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0            Latvia           1.187           1.465                    0.812
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         0.264       0.075                      0.064
#
#      name  region       sub-region  Terrorist_attacks country_name  \
# 0  Latvia  Europe  Northern Europe         125.611111       Latvia
#
#    population  population_below_poverty_line       hdi  life_expectancy  \
# 0   1949670.0                           25.5  0.829862           74.342
#
#    expected_years_of_schooling  mean_years_of_schooling          gni
# 0                     15.97411                11.736418  22589.17355

# %% [markdown]
# # 2. Exploratory Data Analysis

# %%
num_missing_values = X_train.isnull().sum()
missing_percentage = (X_train.isnull().sum() / len(X_train)) * 100

missing_data = pd.DataFrame({
    'Missing Values': num_missing_values,
    'Percentage': missing_percentage
})

display(missing_data)
# Out:
#                                Missing Values  Percentage
# Country or region                           0    0.000000
# GDP per capita                              0    0.000000
# Social support                              0    0.000000
# Healthy life expectancy                     0    0.000000
# Freedom to make life choices                0    0.000000
# Generosity                                  0    0.000000
# Perceptions of corruption                   0    0.000000
# name                                        0    0.000000
# region                                      0    0.000000
# sub-region                                  0    0.000000
# Terrorist_attacks                           0    0.000000
# country_name                                6    8.695652
# population                                  6    8.695652
# population_below_poverty_line              11   15.942029
# hdi                                         6    8.695652
# life_expectancy                             6    8.695652
# expected_years_of_schooling                 6    8.695652
# mean_years_of_schooling                     6    8.695652
# gni                                         6    8.695652

# %%
# I chose to plot the distribution of 'gdp per capita', distribution of 'life_expectancy', 
# distribution of 'Freedom to make life choices', and distribution of 'Mean Years of Schooling'. 

import matplotlib.pyplot as plt

import matplotlib.pyplot as plt

# Assuming X_train is your DataFrame and it is already defined.
plot_data_1 = X_train["GDP per capita"]
plot_data_2 = X_train["life_expectancy"]
plot_data_3 = X_train["Freedom to make life choices"]
plot_data_4 = X_train["mean_years_of_schooling"]

# Create a figure with 2x2 subplots
figure, axs = plt.subplots(2, 2, figsize=(12, 10))

# Plot histogram for GDP per capita
axs[0, 0].hist(plot_data_1, bins=10, color='blue', edgecolor='black', alpha=0.7)
axs[0, 0].set_title('Histogram of GDP per capita')
axs[0, 0].set_xlabel('GDP per capita')
axs[0, 0].set_ylabel('Frequency')

# Plot histogram for Life Expectancy
axs[0, 1].hist(plot_data_2, bins=10, color='skyblue', edgecolor='black', alpha=0.7)
axs[0, 1].set_title('Histogram of Life Expectancy')
axs[0, 1].set_xlabel('Life Expectancy')
axs[0, 1].set_ylabel('Frequency')

# Plot histogram for Freedom to make life choices
axs[1, 0].hist(plot_data_3, bins=10, color='green', edgecolor='black', alpha=0.7)
axs[1, 0].set_title('Histogram of Freedom to make life choices')
axs[1, 0].set_xlabel('Freedom to make life choices')
axs[1, 0].set_ylabel('Frequency')

# Plot histogram for Mean Years of Schooling
axs[1, 1].hist(plot_data_4, bins=10, color='orange', edgecolor='black', alpha=0.7)
axs[1, 1].set_title('Histogram of Mean Years of Schooling')
axs[1, 1].set_xlabel('Mean Years of Schooling')
axs[1, 1].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
# I chose to plot the distribution of categorical variable "region" and 'sub_region'.

region_category_counts = X_train['region'].value_counts()
plt.figure(figsize=(12, 6))
plt.bar(region_category_counts.index, region_category_counts.values)
plt.xlabel('Categories')
plt.ylabel('Counts')
plt.title('Distribution of Region')
plt.show()

sub_region_category_counts = X_train['sub-region'].value_counts()
plt.figure(figsize=(12, 6))
plt.bar(sub_region_category_counts.index, sub_region_category_counts.values)
plt.xlabel('Categories')
plt.ylabel('Counts')
plt.title('Distribution of Sub-region')
plt.xticks(rotation=90)
plt.show()

# %%
# I chose to explore the relationship between 'gdp per capita' and 'life_expectancy', as well as the relationship 
# between 'mean_years_of_schooling' and 'life_expectancy'.

# From the scatter plots, we observe that both 'GDP per capita' and 'mean years of schooling' have a positive 
# relationship with 'life expectancy'.


plt.scatter(X_train['GDP per capita'], X_train['life_expectancy'])
plt.xlabel('GDP per capita')
plt.ylabel('Life Expectancy')
plt.title('Scatter Plot of GDP per capita vs. Life Expectancy')
plt.grid()
plt.show()

plt.scatter(X_train['mean_years_of_schooling'], X_train['life_expectancy'])
plt.xlabel('Mean Years of schooling')
plt.ylabel('Life Expectancy')
plt.title('Mean Years of schooling vs. Life Expectancy')
plt.grid()
plt.show()

# %%
# Correlation table
# From the correlation table, almost all attributes show a positive correlation with 'life_expectancy','except for 
# 'Generosity,' 'Terrorist_attacks,' and 'population_below_poverty_line'.

correlation_matrix = X_train.corr()
display(correlation_matrix)
# Out:
# /var/folders/xl/1l26f1zs64vcyrn4b8yynjl00000gn/T/ipykernel_60128/1675485758.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = X_train.corr()
#                                GDP per capita  Social support  \
# GDP per capita                       1.000000        0.776994
# Social support                       0.776994        1.000000
# Healthy life expectancy              0.828855        0.732568
# Freedom to make life choices         0.497536        0.588616
# Generosity                          -0.087230       -0.058026
# Perceptions of corruption            0.376035        0.290184
# Terrorist_attacks                   -0.359662       -0.445112
# population                           0.010983       -0.078932
# population_below_poverty_line       -0.783629       -0.671441
# hdi                                  0.952534        0.829772
# life_expectancy                      0.819725        0.713381
# expected_years_of_schooling          0.816278        0.763511
# mean_years_of_schooling              0.806770        0.794848
# gni                                  0.791134        0.501397
#
#                                Healthy life expectancy  \
# GDP per capita                                0.828855
# Social support                                0.732568
# Healthy life expectancy                       1.000000
# Freedom to make life choices                  0.424599
# Generosity                                   -0.017666
# Perceptions of corruption                     0.379915
# Terrorist_attacks                            -0.402194
# population                                    0.056740
# population_below_poverty_line                -0.698012
# hdi                                           0.919899
# life_expectancy                               0.982990
# expected_years_of_schooling                   0.837451
# mean_years_of_schooling                       0.795686
# gni                                           0.570419
#
#                                Freedom to make life choices  Generosity  \
# GDP per capita                                     0.497536   -0.087230
# Social support                                     0.588616   -0.058026
# Healthy life expectancy                            0.424599   -0.017666
# Freedom to make life choices                       1.000000    0.302245
# Generosity                                         0.302245    1.000000
# Perceptions of corruption                          0.493557    0.274878
# Terrorist_attacks                                 -0.381656    0.027501
# population                                         0.111773   -0.075887
# population_below_poverty_line                     -0.405978    0.069264
# hdi                                                0.428954   -0.123773
# life_expectancy                                    0.392675   -0.017838
# expected_years_of_schooling                        0.356783   -0.141452
# mean_years_of_schooling                            0.346807   -0.147592
# gni                                                0.457114    0.031449
#
#                                Perceptions of corruption  Terrorist_attacks  \
# GDP per capita                                  0.376035          -0.359662
# Social support                                  0.290184          -0.445112
# Healthy life expectancy                         0.379915          -0.402194
# Freedom to make life choices                    0.493557          -0.381656
# Generosity                                      0.274878           0.027501
# Perceptions of corruption                       1.000000          -0.172918
# Terrorist_attacks                              -0.172918           1.000000
# population                                     -0.053192          -0.033408
# population_below_poverty_line                  -0.216316           0.271698
# hdi                                             0.367459          -0.362150
# life_expectancy                                 0.361583          -0.346591
# expected_years_of_schooling                     0.319262          -0.258710
# mean_years_of_schooling                         0.316947          -0.395745
# gni                                             0.463926          -0.219806
#
#                                population  population_below_poverty_line  \
# GDP per capita                   0.010983                      -0.783629
# Social support                  -0.078932                      -0.671441
# Healthy life expectancy          0.056740                      -0.698012
# Freedom to make life choices     0.111773                      -0.405978
# Generosity                      -0.075887                       0.069264
# Perceptions of corruption       -0.053192                      -0.216316
# Terrorist_attacks               -0.033408                       0.271698
# population                       1.000000                      -0.206060
# population_below_poverty_line   -0.206060                       1.000000
# hdi                             -0.011924                      -0.763920
# life_expectancy                  0.034366                      -0.675131
# expected_years_of_schooling     -0.015770                      -0.654276
# mean_years_of_schooling         -0.094350                      -0.689748
# gni                             -0.072591                      -0.557626
#
#                                     hdi  life_expectancy  \
# GDP per capita                 0.952534         0.819725
# Social support                 0.829772         0.713381
# Healthy life expectancy        0.919899         0.982990
# Freedom to make life choices   0.428954         0.392675
# Generosity                    -0.123773        -0.017838
# Perceptions of corruption      0.367459         0.361583
# Terrorist_attacks             -0.362150        -0.346591
# population                    -0.011924         0.034366
# population_below_poverty_line -0.763920        -0.675131
# hdi                            1.000000         0.904335
# life_expectancy                0.904335         1.000000
# expected_years_of_schooling    0.920350         0.810396
# mean_years_of_schooling        0.907800         0.744140
# gni                            0.662804         0.586960
#
#                                expected_years_of_schooling  \
# GDP per capita                                    0.816278
# Social support                                    0.763511
# Healthy life expectancy                           0.837451
# Freedom to make life choices                      0.356783
# Generosity                                       -0.141452
# Perceptions of corruption                         0.319262
# Terrorist_attacks                                -0.258710
# population                                       -0.015770
# population_below_poverty_line                    -0.654276
# hdi                                               0.920350
# life_expectancy                                   0.810396
# expected_years_of_schooling                       1.000000
# mean_years_of_schooling                           0.842120
# gni                                               0.492256
#
#                                mean_years_of_schooling       gni
# GDP per capita                                0.806770  0.791134
# Social support                                0.794848  0.501397
# Healthy life expectancy                       0.795686  0.570419
# Freedom to make life choices                  0.346807  0.457114
# Generosity                                   -0.147592  0.031449
# Perceptions of corruption                     0.316947  0.463926
# Terrorist_attacks                            -0.395745 -0.219806
# population                                   -0.094350 -0.072591
# population_below_poverty_line                -0.689748 -0.557626
# hdi                                           0.907800  0.662804
# life_expectancy                               0.744140  0.586960
# expected_years_of_schooling                   0.842120  0.492256
# mean_years_of_schooling                       1.000000  0.497668
# gni                                           0.497668  1.000000

# %% [markdown]
# I observed that 'Generosity,' 'Terrorist_attacks,' and 'population_below_poverty_line' have negative relationship with 'life_expectancy'.This makes sense, as an increase in terrorist attacks and the proportion of poor people in a country is likely to result in a decrease in life expectancy in that country. To my surprise, 'Generosity' shows a negative correlation with 'life_expectancy'. Some countries may be overly generous in ways that lead to unsustainable economic practices, which negatively impact living conditions.
#
# I observed that as GDP per capita increases, life expectancy also improves. Additionally, as the number of years of schooling increases, life expectancy tends to rise as well. These observations suggest that improving both economic conditions and educational access can enhance public health outcomes.

# %% [markdown]
# # 3. Preprocess data using a Pipeline

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# Create the preprocessing pipelines for both numeric and categorical data.

numeric_features = X_train.select_dtypes(include=['number'])## Drop all the non-numerical features from X_train
numeric_features=numeric_features.columns.tolist()

numeric_transformer = Pipeline(steps=[
#    ('imputer', SimpleImputer(strategy='constant', fill_value=0)), ## Is this good enough?
    ('imputer', SimpleImputer(strategy='median')), ## I change the fill_value from zero to median.
    ('scaler', StandardScaler())]) # You will need to describe why this is being done in the next cell

categorical_features = ['region', 'sub-region']

#Replacing missing values with Modal value and then one hot encoding.
categorical_transformer = Pipeline(steps=[
    ('imputer',  SimpleImputer(strategy='most_frequent' )),
    ('onehot', OneHotEncoder(handle_unknown= 'ignore'  ))])

# final preprocessor object set up with ColumnTransformer
preprocessor = ColumnTransformer(transformers=[('num', numeric_transformer, numeric_features),('cat', categorical_transformer, categorical_features)])

#Fit your preprocessor object
preprocess=preprocessor.fit(X_train)

# %%
def preprocessor(data):
    data.drop(['Country or region', 'name'], axis=1)
    preprocessed_data=preprocess.transform(data)
    return preprocessed_data

# %% [markdown]
# # 4. Fit the Keras model on the preprocessed data and save the preprocessor function along with the Keras model.

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation
from tensorflow.keras.optimizers import SGD

feature_count= preprocessor(X_train).shape[1]#count features in input data

keras_model = Sequential() ## Define a Neural Network Model with 5 layers 128->64->64->32->(?)
keras_model.add(Dense(128, activation='relu', input_dim=feature_count))
keras_model.add(Dense(64, activation='relu'))
keras_model.add(Dense(64, activation='relu'))
keras_model.add(Dense(32, activation='relu'))
#Use Softmax activation in last layer. How many neurons should there be in the last layer?
#The y_train includes 5 columns, so 5 neurons should be in the output layer.
keras_model.add(Dense(5, activation='softmax'))
sgd = SGD(learning_rate=0.0001)

# Compile model
keras_model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# Fitting the NN to the Training set
history = keras_model.fit(preprocessor(X_train), y_train, ## Note that keras models require a one-hot-encoded y_train object
               batch_size = 20,
               epochs = 300, validation_split=0.25)

loss = history.history['loss']
val_loss = history.history['val_loss']
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
# Out:
# 2024-10-07 15:10:36.946507: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /Users/anyuchen/opt/anaconda3/lib/python3.9/site-packages/keras/src/layers/core/dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.0963 - loss: 1.6580 - val_accuracy: 0.2222 - val_loss: 1.6047
# Epoch 2/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.1151 - loss: 1.6439 - val_accuracy: 0.2778 - val_loss: 1.5986
# Epoch 3/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.1338 - loss: 1.6333 - val_accuracy: 0.2778 - val_loss: 1.5927
# Epoch 4/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.1186 - loss: 1.6410 - val_accuracy: 0.2778 - val_loss: 1.5876
# Epoch 5/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1436 - loss: 1.6189 - val_accuracy: 0.3333 - val_loss: 1.5828
# Epoch 6/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1632 - loss: 1.6144 - val_accuracy: 0.3333 - val_loss: 1.5779
# Epoch 7/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.1543 - loss: 1.6145 - val_accuracy: 0.3333 - val_loss: 1.5721
# Epoch 8/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1989 - loss: 1.6111 - val_accuracy: 0.3333 - val_loss: 1.5660
# Epoch 9/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3096 - loss: 1.5705 - val_accuracy: 0.3333 - val_loss: 1.5605
# Epoch 10/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2596 - loss: 1.5825 - val_accuracy: 0.3889 - val_loss: 1.5548
# Epoch 11/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2944 - loss: 1.5622 - val_accuracy: 0.3889 - val_loss: 1.5490
# Epoch 12/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3131 - loss: 1.5535 - val_accuracy: 0.3889 - val_loss: 1.5433
# Epoch 13/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3425 - loss: 1.5515 - val_accuracy: 0.3889 - val_loss: 1.5377
# Epoch 14/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3836 - loss: 1.5306 - val_accuracy: 0.3889 - val_loss: 1.5318
# Epoch 15/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4059 - loss: 1.5237 - val_accuracy: 0.4444 - val_loss: 1.5257
# Epoch 16/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3880 - loss: 1.5197 - val_accuracy: 0.5000 - val_loss: 1.5189
# Epoch 17/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3692 - loss: 1.5203 - val_accuracy: 0.5000 - val_loss: 1.5128
# Epoch 18/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4478 - loss: 1.4986 - val_accuracy: 0.5000 - val_loss: 1.5071
# Epoch 19/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5701 - loss: 1.4706 - val_accuracy: 0.5000 - val_loss: 1.5029
# Epoch 20/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4826 - loss: 1.4713 - val_accuracy: 0.5000 - val_loss: 1.4978
# Epoch 21/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4638 - loss: 1.4996 - val_accuracy: 0.4444 - val_loss: 1.4921
# Epoch 22/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5683 - loss: 1.4775 - val_accuracy: 0.5000 - val_loss: 1.4865
# Epoch 23/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5718 - loss: 1.4361 - val_accuracy: 0.5000 - val_loss: 1.4810
# Epoch 24/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5245 - loss: 1.4352 - val_accuracy: 0.5000 - val_loss: 1.4762
# Epoch 25/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5718 - loss: 1.4244 - val_accuracy: 0.5000 - val_loss: 1.4713
# Epoch 26/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5914 - loss: 1.4196 - val_accuracy: 0.6111 - val_loss: 1.4671
# Epoch 27/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6637 - loss: 1.4239 - val_accuracy: 0.6111 - val_loss: 1.4628
# Epoch 28/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6262 - loss: 1.4180 - val_accuracy: 0.6111 - val_loss: 1.4578
# Epoch 29/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6423 - loss: 1.3928 - val_accuracy: 0.6111 - val_loss: 1.4527
# Epoch 30/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6825 - loss: 1.3368 - val_accuracy: 0.6111 - val_loss: 1.4474
# Epoch 31/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5950 - loss: 1.3654 - val_accuracy: 0.6111 - val_loss: 1.4418
# Epoch 32/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6325 - loss: 1.3458 - val_accuracy: 0.6111 - val_loss: 1.4375
# Epoch 33/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6235 - loss: 1.3818 - val_accuracy: 0.6111 - val_loss: 1.4322
# Epoch 34/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6298 - loss: 1.3505 - val_accuracy: 0.6111 - val_loss: 1.4277
# Epoch 35/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7146 - loss: 1.3034 - val_accuracy: 0.5556 - val_loss: 1.4233
# Epoch 36/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6583 - loss: 1.3167 - val_accuracy: 0.5556 - val_loss: 1.4181
# Epoch 37/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6235 - loss: 1.3512 - val_accuracy: 0.5556 - val_loss: 1.4136
# Epoch 38/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6610 - loss: 1.2963 - val_accuracy: 0.5556 - val_loss: 1.4095
# Epoch 39/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6485 - loss: 1.3015 - val_accuracy: 0.5000 - val_loss: 1.4043
# Epoch 40/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6485 - loss: 1.2812 - val_accuracy: 0.5000 - val_loss: 1.3997
# Epoch 41/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6110 - loss: 1.2865 - val_accuracy: 0.5000 - val_loss: 1.3940
# Epoch 42/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6610 - loss: 1.2803 - val_accuracy: 0.5000 - val_loss: 1.3895
# Epoch 43/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5860 - loss: 1.3233 - val_accuracy: 0.5000 - val_loss: 1.3847
# Epoch 44/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6173 - loss: 1.2512 - val_accuracy: 0.5000 - val_loss: 1.3809
# Epoch 45/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6173 - loss: 1.2675 - val_accuracy: 0.5000 - val_loss: 1.3750
# Epoch 46/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6485 - loss: 1.2538 - val_accuracy: 0.5556 - val_loss: 1.3699
# Epoch 47/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6325 - loss: 1.2396 - val_accuracy: 0.5556 - val_loss: 1.3645
# Epoch 48/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6860 - loss: 1.2276 - val_accuracy: 0.5556 - val_loss: 1.3617
# Epoch 49/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6548 - loss: 1.1814 - val_accuracy: 0.5556 - val_loss: 1.3570
# Epoch 50/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6075 - loss: 1.2182 - val_accuracy: 0.5556 - val_loss: 1.3525
# Epoch 51/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6075 - loss: 1.1947 - val_accuracy: 0.5556 - val_loss: 1.3479
# Epoch 52/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6262 - loss: 1.1527 - val_accuracy: 0.5556 - val_loss: 1.3429
# Epoch 53/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6262 - loss: 1.1603 - val_accuracy: 0.5556 - val_loss: 1.3387
# Epoch 54/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6137 - loss: 1.1675 - val_accuracy: 0.5556 - val_loss: 1.3345
# Epoch 55/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6137 - loss: 1.1300 - val_accuracy: 0.5556 - val_loss: 1.3302
# Epoch 56/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5887 - loss: 1.2020 - val_accuracy: 0.5556 - val_loss: 1.3265
# Epoch 57/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6012 - loss: 1.1442 - val_accuracy: 0.5556 - val_loss: 1.3225
# Epoch 58/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6512 - loss: 1.0705 - val_accuracy: 0.5556 - val_loss: 1.3175
# Epoch 59/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6012 - loss: 1.1277 - val_accuracy: 0.5556 - val_loss: 1.3144
# Epoch 60/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5887 - loss: 1.1452 - val_accuracy: 0.5556 - val_loss: 1.3112
# Epoch 61/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6360 - loss: 1.0907 - val_accuracy: 0.5556 - val_loss: 1.3072
# Epoch 62/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6048 - loss: 1.1332 - val_accuracy: 0.5556 - val_loss: 1.3032
# Epoch 63/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6798 - loss: 1.0884 - val_accuracy: 0.5556 - val_loss: 1.2997
# Epoch 64/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6610 - loss: 1.0369 - val_accuracy: 0.5556 - val_loss: 1.2937
# Epoch 65/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6681 - loss: 1.0643 - val_accuracy: 0.5000 - val_loss: 1.2901
# Epoch 66/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6904 - loss: 1.0526 - val_accuracy: 0.5000 - val_loss: 1.2845
# Epoch 67/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6967 - loss: 1.0820 - val_accuracy: 0.5000 - val_loss: 1.2827
# Epoch 68/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7217 - loss: 1.0198 - val_accuracy: 0.6111 - val_loss: 1.2751
# Epoch 69/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7467 - loss: 0.9818 - val_accuracy: 0.6111 - val_loss: 1.2700
# Epoch 70/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7565 - loss: 0.9788 - val_accuracy: 0.6111 - val_loss: 1.2650
# Epoch 71/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6842 - loss: 1.0233 - val_accuracy: 0.6111 - val_loss: 1.2625
# Epoch 72/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6717 - loss: 1.0569 - val_accuracy: 0.5556 - val_loss: 1.2594
# Epoch 73/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6967 - loss: 0.9804 - val_accuracy: 0.6111 - val_loss: 1.2538
# Epoch 74/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7154 - loss: 0.9350 - val_accuracy: 0.6111 - val_loss: 1.2494
# Epoch 75/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6842 - loss: 1.0125 - val_accuracy: 0.6111 - val_loss: 1.2434
# Epoch 76/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7065 - loss: 1.0145 - val_accuracy: 0.6111 - val_loss: 1.2401
# Epoch 77/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7690 - loss: 0.9568 - val_accuracy: 0.6111 - val_loss: 1.2348
# Epoch 78/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7127 - loss: 0.9675 - val_accuracy: 0.6111 - val_loss: 1.2341
# Epoch 79/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7475 - loss: 0.9241 - val_accuracy: 0.6111 - val_loss: 1.2298
# Epoch 80/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7600 - loss: 0.8952 - val_accuracy: 0.6111 - val_loss: 1.2246
# Epoch 81/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7163 - loss: 0.9478 - val_accuracy: 0.6111 - val_loss: 1.2215
# Epoch 82/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7511 - loss: 0.9499 - val_accuracy: 0.6111 - val_loss: 1.2166
# Epoch 83/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7288 - loss: 0.9866 - val_accuracy: 0.6111 - val_loss: 1.2153
# Epoch 84/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7761 - loss: 0.9015 - val_accuracy: 0.6111 - val_loss: 1.2096
# Epoch 85/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7824 - loss: 0.8649 - val_accuracy: 0.6111 - val_loss: 1.2053
# Epoch 86/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7511 - loss: 0.9130 - val_accuracy: 0.6111 - val_loss: 1.2024
# Epoch 87/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7386 - loss: 0.8272 - val_accuracy: 0.6667 - val_loss: 1.1950
# Epoch 88/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7386 - loss: 0.9215 - val_accuracy: 0.6667 - val_loss: 1.1911
# Epoch 89/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7574 - loss: 0.8790 - val_accuracy: 0.6111 - val_loss: 1.1895
# Epoch 90/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7886 - loss: 0.8217 - val_accuracy: 0.6667 - val_loss: 1.1854
# Epoch 91/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7734 - loss: 0.8832 - val_accuracy: 0.6667 - val_loss: 1.1821
# Epoch 92/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7922 - loss: 0.8798 - val_accuracy: 0.6667 - val_loss: 1.1794
# Epoch 93/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7734 - loss: 0.8633 - val_accuracy: 0.6667 - val_loss: 1.1748
# Epoch 94/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7734 - loss: 0.8658 - val_accuracy: 0.6667 - val_loss: 1.1701
# Epoch 95/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7922 - loss: 0.8284 - val_accuracy: 0.6667 - val_loss: 1.1682
# Epoch 96/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7797 - loss: 0.8328 - val_accuracy: 0.6667 - val_loss: 1.1631
# Epoch 97/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7922 - loss: 0.8212 - val_accuracy: 0.6667 - val_loss: 1.1606
# Epoch 98/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8047 - loss: 0.8339 - val_accuracy: 0.6111 - val_loss: 1.1589
# Epoch 99/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8172 - loss: 0.7676 - val_accuracy: 0.6111 - val_loss: 1.1549
# Epoch 100/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7922 - loss: 0.7824 - val_accuracy: 0.6111 - val_loss: 1.1499
# Epoch 101/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8234 - loss: 0.7954 - val_accuracy: 0.5556 - val_loss: 1.1477
# Epoch 102/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7484 - loss: 0.8108 - val_accuracy: 0.6111 - val_loss: 1.1429
# Epoch 103/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7797 - loss: 0.8069 - val_accuracy: 0.5556 - val_loss: 1.1432
# Epoch 104/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8109 - loss: 0.7648 - val_accuracy: 0.5556 - val_loss: 1.1400
# Epoch 105/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7734 - loss: 0.7966 - val_accuracy: 0.5556 - val_loss: 1.1378
# Epoch 106/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8234 - loss: 0.7524 - val_accuracy: 0.5556 - val_loss: 1.1368
# Epoch 107/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7922 - loss: 0.7721 - val_accuracy: 0.5556 - val_loss: 1.1338
# Epoch 108/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8297 - loss: 0.7243 - val_accuracy: 0.5556 - val_loss: 1.1302
# Epoch 109/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8047 - loss: 0.7681 - val_accuracy: 0.5556 - val_loss: 1.1293
# Epoch 110/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7922 - loss: 0.7302 - val_accuracy: 0.5556 - val_loss: 1.1233
# Epoch 111/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7859 - loss: 0.7757 - val_accuracy: 0.5556 - val_loss: 1.1194
# Epoch 112/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7984 - loss: 0.7165 - val_accuracy: 0.5556 - val_loss: 1.1171
# Epoch 113/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7672 - loss: 0.7543 - val_accuracy: 0.5556 - val_loss: 1.1131
# Epoch 114/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8609 - loss: 0.6558 - val_accuracy: 0.5556 - val_loss: 1.1091
# Epoch 115/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8047 - loss: 0.7245 - val_accuracy: 0.5556 - val_loss: 1.1090
# Epoch 116/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7797 - loss: 0.7239 - val_accuracy: 0.5556 - val_loss: 1.1046
# Epoch 117/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7297 - loss: 0.7715 - val_accuracy: 0.5556 - val_loss: 1.1025
# Epoch 118/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7984 - loss: 0.7027 - val_accuracy: 0.5556 - val_loss: 1.1016
# Epoch 119/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7984 - loss: 0.7102 - val_accuracy: 0.5556 - val_loss: 1.0991
# Epoch 120/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7734 - loss: 0.6847 - val_accuracy: 0.5556 - val_loss: 1.0970
# Epoch 121/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7297 - loss: 0.7600 - val_accuracy: 0.5556 - val_loss: 1.0918
# Epoch 122/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7734 - loss: 0.7027 - val_accuracy: 0.5556 - val_loss: 1.0870
# Epoch 123/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7609 - loss: 0.7107 - val_accuracy: 0.5556 - val_loss: 1.0843
# Epoch 124/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7422 - loss: 0.7294 - val_accuracy: 0.5556 - val_loss: 1.0835
# Epoch 125/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7734 - loss: 0.6870 - val_accuracy: 0.5556 - val_loss: 1.0811
# Epoch 126/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7922 - loss: 0.6890 - val_accuracy: 0.5556 - val_loss: 1.0773
# Epoch 127/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7984 - loss: 0.6207 - val_accuracy: 0.5556 - val_loss: 1.0777
# Epoch 128/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8109 - loss: 0.6079 - val_accuracy: 0.5556 - val_loss: 1.0732
# Epoch 129/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8172 - loss: 0.6224 - val_accuracy: 0.5556 - val_loss: 1.0690
# Epoch 130/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7734 - loss: 0.6028 - val_accuracy: 0.5556 - val_loss: 1.0678
# Epoch 131/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7984 - loss: 0.6357 - val_accuracy: 0.5556 - val_loss: 1.0685
# Epoch 132/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7797 - loss: 0.6210 - val_accuracy: 0.5556 - val_loss: 1.0662
# Epoch 133/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7859 - loss: 0.6446 - val_accuracy: 0.5556 - val_loss: 1.0675
# Epoch 134/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7672 - loss: 0.6579 - val_accuracy: 0.5556 - val_loss: 1.0688
# Epoch 135/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7922 - loss: 0.6391 - val_accuracy: 0.5556 - val_loss: 1.0708
# Epoch 136/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7609 - loss: 0.6249 - val_accuracy: 0.5556 - val_loss: 1.0641
# Epoch 137/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7922 - loss: 0.6036 - val_accuracy: 0.5000 - val_loss: 1.0613
# Epoch 138/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8297 - loss: 0.5640 - val_accuracy: 0.5000 - val_loss: 1.0551
# Epoch 139/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8234 - loss: 0.5626 - val_accuracy: 0.5000 - val_loss: 1.0509
# Epoch 140/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7797 - loss: 0.5928 - val_accuracy: 0.5000 - val_loss: 1.0450
# Epoch 141/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7984 - loss: 0.5871 - val_accuracy: 0.5000 - val_loss: 1.0451
# Epoch 142/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8082 - loss: 0.5630 - val_accuracy: 0.5000 - val_loss: 1.0461
# Epoch 143/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7520 - loss: 0.6157 - val_accuracy: 0.5000 - val_loss: 1.0441
# Epoch 144/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8020 - loss: 0.5831 - val_accuracy: 0.5000 - val_loss: 1.0413
# Epoch 145/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8020 - loss: 0.5630 - val_accuracy: 0.5000 - val_loss: 1.0394
# Epoch 146/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7895 - loss: 0.6195 - val_accuracy: 0.5000 - val_loss: 1.0414
# Epoch 147/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7832 - loss: 0.5961 - val_accuracy: 0.5000 - val_loss: 1.0390
# Epoch 148/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8207 - loss: 0.5466 - val_accuracy: 0.5000 - val_loss: 1.0357
# Epoch 149/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8430 - loss: 0.5541 - val_accuracy: 0.5000 - val_loss: 1.0338
# Epoch 150/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8243 - loss: 0.5831 - val_accuracy: 0.5000 - val_loss: 1.0337
# Epoch 151/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8180 - loss: 0.5817 - val_accuracy: 0.5000 - val_loss: 1.0322
# Epoch 152/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8180 - loss: 0.5532 - val_accuracy: 0.5000 - val_loss: 1.0308
# Epoch 153/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8430 - loss: 0.5571 - val_accuracy: 0.5000 - val_loss: 1.0274
# Epoch 154/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7993 - loss: 0.5683 - val_accuracy: 0.5000 - val_loss: 1.0290
# Epoch 155/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8680 - loss: 0.4651 - val_accuracy: 0.5000 - val_loss: 1.0297
# Epoch 156/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8055 - loss: 0.5449 - val_accuracy: 0.5000 - val_loss: 1.0253
# Epoch 157/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8180 - loss: 0.5393 - val_accuracy: 0.5000 - val_loss: 1.0230
# Epoch 158/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8055 - loss: 0.5745 - val_accuracy: 0.5000 - val_loss: 1.0224
# Epoch 159/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8368 - loss: 0.5055 - val_accuracy: 0.5000 - val_loss: 1.0203
# Epoch 160/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8305 - loss: 0.5485 - val_accuracy: 0.5000 - val_loss: 1.0130
# Epoch 161/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8118 - loss: 0.5205 - val_accuracy: 0.5000 - val_loss: 1.0148
# Epoch 162/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8430 - loss: 0.5047 - val_accuracy: 0.5000 - val_loss: 1.0156
# Epoch 163/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8368 - loss: 0.5025 - val_accuracy: 0.5000 - val_loss: 1.0113
# Epoch 164/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7930 - loss: 0.5806 - val_accuracy: 0.5000 - val_loss: 1.0128
# Epoch 165/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7993 - loss: 0.5230 - val_accuracy: 0.5556 - val_loss: 1.0132
# Epoch 166/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8243 - loss: 0.5285 - val_accuracy: 0.5556 - val_loss: 1.0102
# Epoch 167/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8118 - loss: 0.4975 - val_accuracy: 0.5556 - val_loss: 1.0088
# Epoch 168/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7993 - loss: 0.5440 - val_accuracy: 0.5556 - val_loss: 1.0052
# Epoch 169/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8118 - loss: 0.5141 - val_accuracy: 0.5556 - val_loss: 1.0061
# Epoch 170/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8618 - loss: 0.4527 - val_accuracy: 0.5556 - val_loss: 1.0038
# Epoch 171/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8368 - loss: 0.4464 - val_accuracy: 0.5556 - val_loss: 1.0009
# Epoch 172/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8305 - loss: 0.4651 - val_accuracy: 0.5556 - val_loss: 0.9957
# Epoch 173/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8305 - loss: 0.4601 - val_accuracy: 0.5556 - val_loss: 0.9922
# Epoch 174/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8591 - loss: 0.4385 - val_accuracy: 0.5556 - val_loss: 0.9887
# Epoch 175/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8403 - loss: 0.4966 - val_accuracy: 0.5556 - val_loss: 0.9880
# Epoch 176/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8466 - loss: 0.4629 - val_accuracy: 0.5556 - val_loss: 0.9882
# Epoch 177/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8341 - loss: 0.4859 - val_accuracy: 0.5556 - val_loss: 0.9891
# Epoch 178/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8716 - loss: 0.4435 - val_accuracy: 0.5556 - val_loss: 0.9876
# Epoch 179/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8466 - loss: 0.4324 - val_accuracy: 0.5556 - val_loss: 0.9833
# Epoch 180/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8778 - loss: 0.4651 - val_accuracy: 0.5556 - val_loss: 0.9817
# Epoch 181/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8528 - loss: 0.4619 - val_accuracy: 0.5556 - val_loss: 0.9769
# Epoch 182/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7966 - loss: 0.4952 - val_accuracy: 0.5556 - val_loss: 0.9770
# Epoch 183/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8466 - loss: 0.4662 - val_accuracy: 0.6111 - val_loss: 0.9751
# Epoch 184/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8341 - loss: 0.4618 - val_accuracy: 0.6111 - val_loss: 0.9743
# Epoch 185/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8278 - loss: 0.4774 - val_accuracy: 0.6111 - val_loss: 0.9736
# Epoch 186/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8591 - loss: 0.4401 - val_accuracy: 0.6111 - val_loss: 0.9725
# Epoch 187/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8716 - loss: 0.3983 - val_accuracy: 0.6111 - val_loss: 0.9712
# Epoch 188/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8028 - loss: 0.5105 - val_accuracy: 0.6111 - val_loss: 0.9716
# Epoch 189/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8591 - loss: 0.4560 - val_accuracy: 0.6111 - val_loss: 0.9713
# Epoch 190/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8403 - loss: 0.4592 - val_accuracy: 0.6111 - val_loss: 0.9716
# Epoch 191/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8153 - loss: 0.4917 - val_accuracy: 0.6111 - val_loss: 0.9724
# Epoch 192/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8278 - loss: 0.4428 - val_accuracy: 0.6111 - val_loss: 0.9706
# Epoch 193/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8341 - loss: 0.4495 - val_accuracy: 0.6111 - val_loss: 0.9670
# Epoch 194/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8216 - loss: 0.4338 - val_accuracy: 0.6111 - val_loss: 0.9680
# Epoch 195/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8653 - loss: 0.4034 - val_accuracy: 0.6111 - val_loss: 0.9637
# Epoch 196/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8716 - loss: 0.3750 - val_accuracy: 0.6111 - val_loss: 0.9615
# Epoch 197/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8653 - loss: 0.3655 - val_accuracy: 0.6111 - val_loss: 0.9576
# Epoch 198/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8278 - loss: 0.4210 - val_accuracy: 0.6111 - val_loss: 0.9598
# Epoch 199/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8278 - loss: 0.4057 - val_accuracy: 0.6111 - val_loss: 0.9662
# Epoch 200/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7966 - loss: 0.4892 - val_accuracy: 0.6111 - val_loss: 0.9667
# Epoch 201/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8653 - loss: 0.4010 - val_accuracy: 0.6111 - val_loss: 0.9597
# Epoch 202/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7966 - loss: 0.4745 - val_accuracy: 0.6111 - val_loss: 0.9624
# Epoch 203/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8278 - loss: 0.4201 - val_accuracy: 0.6111 - val_loss: 0.9622
# Epoch 204/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8841 - loss: 0.3683 - val_accuracy: 0.6111 - val_loss: 0.9598
# Epoch 205/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8278 - loss: 0.4007 - val_accuracy: 0.6111 - val_loss: 0.9590
# Epoch 206/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8528 - loss: 0.4302 - val_accuracy: 0.6111 - val_loss: 0.9582
# Epoch 207/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8466 - loss: 0.3987 - val_accuracy: 0.6111 - val_loss: 0.9560
# Epoch 208/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8466 - loss: 0.3820 - val_accuracy: 0.6111 - val_loss: 0.9537
# Epoch 209/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8341 - loss: 0.4168 - val_accuracy: 0.6111 - val_loss: 0.9558
# Epoch 210/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8153 - loss: 0.4336 - val_accuracy: 0.6111 - val_loss: 0.9542
# Epoch 211/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8466 - loss: 0.3953 - val_accuracy: 0.6111 - val_loss: 0.9551
# Epoch 212/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8403 - loss: 0.3991 - val_accuracy: 0.6111 - val_loss: 0.9557
# Epoch 213/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8278 - loss: 0.4075 - val_accuracy: 0.6111 - val_loss: 0.9579
# Epoch 214/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8653 - loss: 0.3498 - val_accuracy: 0.6111 - val_loss: 0.9564
# Epoch 215/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8341 - loss: 0.3929 - val_accuracy: 0.6111 - val_loss: 0.9568
# Epoch 216/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8216 - loss: 0.3753 - val_accuracy: 0.6111 - val_loss: 0.9515
# Epoch 217/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8376 - loss: 0.3840 - val_accuracy: 0.6111 - val_loss: 0.9517
# Epoch 218/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8653 - loss: 0.3579 - val_accuracy: 0.6667 - val_loss: 0.9478
# Epoch 219/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8564 - loss: 0.3939 - val_accuracy: 0.6667 - val_loss: 0.9481
# Epoch 220/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8814 - loss: 0.3703 - val_accuracy: 0.6667 - val_loss: 0.9484
# Epoch 221/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8626 - loss: 0.3715 - val_accuracy: 0.6667 - val_loss: 0.9492
# Epoch 222/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8626 - loss: 0.3606 - val_accuracy: 0.6667 - val_loss: 0.9446
# Epoch 223/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8439 - loss: 0.3737 - val_accuracy: 0.6667 - val_loss: 0.9468
# Epoch 224/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8939 - loss: 0.3520 - val_accuracy: 0.6667 - val_loss: 0.9448
# Epoch 225/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8439 - loss: 0.3953 - val_accuracy: 0.6667 - val_loss: 0.9477
# Epoch 226/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8814 - loss: 0.3151 - val_accuracy: 0.6667 - val_loss: 0.9507
# Epoch 227/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8626 - loss: 0.3430 - val_accuracy: 0.6667 - val_loss: 0.9521
# Epoch 228/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8626 - loss: 0.3564 - val_accuracy: 0.6667 - val_loss: 0.9504
# Epoch 229/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8751 - loss: 0.3391 - val_accuracy: 0.6667 - val_loss: 0.9523
# Epoch 230/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8314 - loss: 0.3783 - val_accuracy: 0.6667 - val_loss: 0.9516
# Epoch 231/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8626 - loss: 0.3425 - val_accuracy: 0.6667 - val_loss: 0.9529
# Epoch 232/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8439 - loss: 0.3573 - val_accuracy: 0.6667 - val_loss: 0.9524
# Epoch 233/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8814 - loss: 0.3532 - val_accuracy: 0.6667 - val_loss: 0.9505
# Epoch 234/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8724 - loss: 0.3496 - val_accuracy: 0.6667 - val_loss: 0.9505
# Epoch 235/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8974 - loss: 0.3247 - val_accuracy: 0.6667 - val_loss: 0.9504
# Epoch 236/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8974 - loss: 0.3176 - val_accuracy: 0.6667 - val_loss: 0.9514
# Epoch 237/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9037 - loss: 0.3060 - val_accuracy: 0.6667 - val_loss: 0.9508
# Epoch 238/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8974 - loss: 0.3199 - val_accuracy: 0.6667 - val_loss: 0.9484
# Epoch 239/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8912 - loss: 0.3029 - val_accuracy: 0.6667 - val_loss: 0.9495
# Epoch 240/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8599 - loss: 0.3394 - val_accuracy: 0.6667 - val_loss: 0.9530
# Epoch 241/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8537 - loss: 0.3489 - val_accuracy: 0.6667 - val_loss: 0.9573
# Epoch 242/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8662 - loss: 0.3596 - val_accuracy: 0.6667 - val_loss: 0.9578
# Epoch 243/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9037 - loss: 0.2940 - val_accuracy: 0.6667 - val_loss: 0.9582
# Epoch 244/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8662 - loss: 0.3332 - val_accuracy: 0.6667 - val_loss: 0.9623
# Epoch 245/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8724 - loss: 0.3377 - val_accuracy: 0.6667 - val_loss: 0.9645
# Epoch 246/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8474 - loss: 0.3311 - val_accuracy: 0.6667 - val_loss: 0.9598
# Epoch 247/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8912 - loss: 0.3065 - val_accuracy: 0.6667 - val_loss: 0.9599
# Epoch 248/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8662 - loss: 0.3312 - val_accuracy: 0.6667 - val_loss: 0.9634
# Epoch 249/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8599 - loss: 0.3251 - val_accuracy: 0.6667 - val_loss: 0.9649
# Epoch 250/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8912 - loss: 0.3050 - val_accuracy: 0.6667 - val_loss: 0.9693
# Epoch 251/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9037 - loss: 0.2959 - val_accuracy: 0.6667 - val_loss: 0.9710
# Epoch 252/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8662 - loss: 0.3159 - val_accuracy: 0.6667 - val_loss: 0.9717
# Epoch 253/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8912 - loss: 0.3046 - val_accuracy: 0.6667 - val_loss: 0.9697
# Epoch 254/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8849 - loss: 0.3011 - val_accuracy: 0.6667 - val_loss: 0.9707
# Epoch 255/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8885 - loss: 0.3361 - val_accuracy: 0.6667 - val_loss: 0.9696
# Epoch 256/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8885 - loss: 0.2920 - val_accuracy: 0.6667 - val_loss: 0.9756
# Epoch 257/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9162 - loss: 0.2574 - val_accuracy: 0.6667 - val_loss: 0.9759
# Epoch 258/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8787 - loss: 0.3036 - val_accuracy: 0.6667 - val_loss: 0.9770
# Epoch 259/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9135 - loss: 0.2678 - val_accuracy: 0.6667 - val_loss: 0.9781
# Epoch 260/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8885 - loss: 0.2964 - val_accuracy: 0.6667 - val_loss: 0.9808
# Epoch 261/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9260 - loss: 0.2660 - val_accuracy: 0.6667 - val_loss: 0.9802
# Epoch 262/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9072 - loss: 0.2853 - val_accuracy: 0.6667 - val_loss: 0.9836
# Epoch 263/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9322 - loss: 0.2723 - val_accuracy: 0.6667 - val_loss: 0.9873
# Epoch 264/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9358 - loss: 0.2474 - val_accuracy: 0.6667 - val_loss: 0.9845
# Epoch 265/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9420 - loss: 0.2627 - val_accuracy: 0.6667 - val_loss: 0.9781
# Epoch 266/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9108 - loss: 0.2824 - val_accuracy: 0.6667 - val_loss: 0.9811
# Epoch 267/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9233 - loss: 0.2814 - val_accuracy: 0.6667 - val_loss: 0.9795
# Epoch 268/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9170 - loss: 0.2658 - val_accuracy: 0.6667 - val_loss: 0.9806
# Epoch 269/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9358 - loss: 0.2623 - val_accuracy: 0.6667 - val_loss: 0.9833
# Epoch 270/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9420 - loss: 0.2545 - val_accuracy: 0.6667 - val_loss: 0.9825
# Epoch 271/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9233 - loss: 0.2804 - val_accuracy: 0.6667 - val_loss: 0.9858
# Epoch 272/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9010 - loss: 0.2731 - val_accuracy: 0.6667 - val_loss: 0.9898
# Epoch 273/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9420 - loss: 0.2655 - val_accuracy: 0.6667 - val_loss: 0.9903
# Epoch 274/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9108 - loss: 0.2596 - val_accuracy: 0.6667 - val_loss: 0.9969
# Epoch 275/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9420 - loss: 0.2514 - val_accuracy: 0.6667 - val_loss: 0.9941
# Epoch 276/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8983 - loss: 0.2550 - val_accuracy: 0.6667 - val_loss: 0.9993
# Epoch 277/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9108 - loss: 0.2670 - val_accuracy: 0.6667 - val_loss: 1.0043
# Epoch 278/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9108 - loss: 0.2371 - val_accuracy: 0.6667 - val_loss: 1.0056
# Epoch 279/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9420 - loss: 0.2331 - val_accuracy: 0.6667 - val_loss: 1.0063
# Epoch 280/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9170 - loss: 0.2554 - val_accuracy: 0.6667 - val_loss: 1.0080
# Epoch 281/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9483 - loss: 0.2402 - val_accuracy: 0.6667 - val_loss: 1.0069
# Epoch 282/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9358 - loss: 0.2418 - val_accuracy: 0.6667 - val_loss: 1.0076
# Epoch 283/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9393 - loss: 0.2604 - val_accuracy: 0.6667 - val_loss: 1.0098
# Epoch 284/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9295 - loss: 0.2428 - val_accuracy: 0.6667 - val_loss: 1.0074
# Epoch 285/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9456 - loss: 0.2398 - val_accuracy: 0.6667 - val_loss: 1.0103
# Epoch 286/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9643 - loss: 0.2211 - val_accuracy: 0.6667 - val_loss: 1.0142
# Epoch 287/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9268 - loss: 0.2657 - val_accuracy: 0.6667 - val_loss: 1.0193
# Epoch 288/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9268 - loss: 0.2275 - val_accuracy: 0.6667 - val_loss: 1.0228
# Epoch 289/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9643 - loss: 0.2166 - val_accuracy: 0.6667 - val_loss: 1.0213
# Epoch 290/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9518 - loss: 0.2071 - val_accuracy: 0.6667 - val_loss: 1.0147
# Epoch 291/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9393 - loss: 0.2325 - val_accuracy: 0.6667 - val_loss: 1.0161
# Epoch 292/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9331 - loss: 0.2202 - val_accuracy: 0.6667 - val_loss: 1.0189
# Epoch 293/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9456 - loss: 0.2212 - val_accuracy: 0.6667 - val_loss: 1.0262
# Epoch 294/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9268 - loss: 0.2244 - val_accuracy: 0.6667 - val_loss: 1.0265
# Epoch 295/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9456 - loss: 0.2195 - val_accuracy: 0.6667 - val_loss: 1.0261
# Epoch 296/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9581 - loss: 0.2106 - val_accuracy: 0.6667 - val_loss: 1.0252
# Epoch 297/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9554 - loss: 0.2240 - val_accuracy: 0.6667 - val_loss: 1.0270
# Epoch 298/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9393 - loss: 0.2233 - val_accuracy: 0.6667 - val_loss: 1.0313
# Epoch 299/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9518 - loss: 0.2109 - val_accuracy: 0.6667 - val_loss: 1.0269
# Epoch 300/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9741 - loss: 0.1974 - val_accuracy: 0.6667 - val_loss: 1.0277

# %%
import numpy as np
from sklearn.metrics import classification_report
predictions = keras_model.predict(preprocessor(X_test))
prediction_column_index = np.argmax(predictions, axis=1)# Predict

# extract correct prediction labels
prediction_labels = [y_train.columns[i] for i in prediction_column_index]

## Write code to show model performance by comparing prediction_labels with true labels
true_labels = y_test.values.argmax(axis=1)
print(classification_report(true_labels, prediction_column_index, target_names=y_train.columns))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#               precision    recall  f1-score   support
#
#      Average       0.00      0.00      0.00         4
#         High       0.50      0.40      0.44         5
#          Low       0.50      0.50      0.50         4
#    Very High       0.50      1.00      0.67         2
#     Very Low       0.60      0.75      0.67         4
#
#     accuracy                           0.47        19
#    macro avg       0.42      0.53      0.46        19
# weighted avg       0.42      0.47      0.43        19

# %% [markdown]
# From the classification report, the model has performed poorly overall, as indicated by the accuracy of 0.47 and the low precision and recall for certain classes (notably "Average"). While it performs reasonably well on the "Very High" and "Very Low" classes, the model struggles with other classes, particularly "Average."

# %% [markdown]
# # 5. Analysis of the Keras model performance and its results.

# %%
fig, ax1 = plt.subplots()

# Plotting the loss values
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color='tab:red')
ax1.plot(loss, label='Training Loss', color='red')
ax1.plot(val_loss, label='Validation Loss', color='orange')
ax1.tick_params(axis='y', labelcolor='tab:red')

# Creating a second y-axis for accuracy
ax2 = ax1.twinx()  
ax2.set_ylabel('Accuracy', color='tab:blue')  
ax2.plot(accuracy, label='Training Accuracy', color='blue')
ax2.plot(val_accuracy, label='Validation Accuracy', color='cyan')
ax2.tick_params(axis='y', labelcolor='tab:blue')

plt.title('Training History and Validation Loss/Accuracy')
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# The training history shows a consistent downward trend in the training loss, indicating that the model is effectively learning from the training data. However, a contrasting pattern is observed in the validation loss, which begins to increase toward the end of the training process. This divergence suggests that the model may be overfitting the training data.
#
# I used the ReLU activation function in the middle layers because it effectively introduces non-linearity and is computationally efficient.The reason for using softmax in the last layer is that it is specifically designed for multi-class classification problems. Since y_train contains multiple categories, softmax allows the model to assign probabilities to each class, enabling us to identify the most likely class.
#
#
# Training for 300 epochs might be excessive and is not a good idea. An epoch refers to one complete pass through the entire training dataset. As I tracked the validation loss during training, I found that around the 190th epoch, the validation loss started to increase while the training loss continued to decrease. This is a sign of overfitting, which means that the model is learning the training data too well but is failing to generalize to unseen data. Therefore, training for more epochs is unnecessary.
#
# The loss function 'categorical_crossentropy' is commonly used in multi-class classification problems. We aim to minimize this loss during training, as it quantifies how well the predicted probabilities match the actual class labels.The optimizer 'sgd' updates the model's weights incrementally for for each training batch and helps the model converge towards the minimum loss based on the loss gradient.

# %%
import shap

explainer = shap.DeepExplainer(keras_model, preprocessor(X_train))
shap_values = explainer.shap_values(preprocessor(X_test))

# Average the absolute SHAP values across all instances for each feature
shap_values_combined = shap_values[0]  # Use the first output if you have multiple outputs
mean_shap_values = np.mean(np.abs(shap_values_combined), axis=1)  # Use absolute values for better interpretation

print(mean_shap_values.shape)

# Get feature names from the preprocessor
columns = preprocess.get_feature_names_out()  # Get the feature names after transformation

# Create a DataFrame for easier plotting
shap_df = pd.DataFrame({
    'Feature': columns,
    'Mean SHAP Value': mean_shap_values
})

# Sort the DataFrame by Mean SHAP Value
shap_df = shap_df.sort_values(by='Mean SHAP Value', ascending=True)

# Plot the final bar plot
plt.figure(figsize=(12, 12))
plt.barh(shap_df['Feature'], shap_df['Mean SHAP Value'], color='skyblue')
plt.xlabel('Mean SHAP Value')
plt.title('Mean SHAP Values for All Features')
plt.show()
# Out:
# /Users/anyuchen/opt/anaconda3/lib/python3.9/site-packages/shap/explainers/_deep/deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# (33,)

# %% [markdown]
# SHAP values effectively represent the contribution of each feature to a model's predictions. For example, a mean SHAP value of 0.05 indicates that an increase in GDP per capita is associated is associated with a significant increase in predicted happiness levels. A mean SHAP value of 0.035 suggests that an increase in expected years of schooling is linked to a significant increase in predicted happiness levels. Overall, these SHAP values provide clear and insightful explanations of how my model makes decisions. However, challenges such as model complexity, feature interactions, and data quality can complicate the justification process. Therefore, I think combining SHAP values with clear illustrations of the model and features could enhances overall interpretability.
